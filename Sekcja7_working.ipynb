# %% [markdown]
# # Sekcja 7: Multiindeks i tabele przestawne

# %% [markdown]
# ## 100. Wyszukiwanie danych w multiindeksie - wykład

# %% [markdown]
# ## 101. LAB 1 - Wyszukiwanie danych w multiindeksie

# %%
import pandas as pd
air=pd.read_csv("./Air_Traffic_Passenger_Statistics.csv")

# %%
air.head(5)
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507        Air Canada                          AC
# 4           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3        Air Canada                          AC  International     Canada
# 4        Air Canada                          AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# ...

# %%
air.set_index(["Operating Airline","Activity Period"],inplace=True)

# %%
air.head(5)
# Out:
#                                   Operating Airline IATA Code  \
# Operating Airline Activity Period
# ATA Airlines      200507                                   TZ
#                   200507                                   TZ
#                   200507                                   TZ
# Air Canada        200507                                   AC
#                   200507                                   AC
#
#                                   Published Airline  \
# Operating Airline Activity Period
# ATA Airlines      200507               ATA Airlines
#                   200507               ATA Airlines
#                   200507               ATA Airlines
# Air Canada        200507                 Air Canada
#                   200507                 Air Canada
#
#                                   Published Airline IATA Code    GEO Summary  \
# Operating Airline Activity Period
# ATA Airlines      200507                                   TZ       Domestic
# ...

# %%
air.reset_index(inplace=True)

# %%
air.head(5)
# Out:
#   Operating Airline  Activity Period Operating Airline IATA Code  \
# 0      ATA Airlines           200507                          TZ
# 1      ATA Airlines           200507                          TZ
# 2      ATA Airlines           200507                          TZ
# 3        Air Canada           200507                          AC
# 4        Air Canada           200507                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3        Air Canada                          AC  International     Canada
# 4        Air Canada                          AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# ...

# %%
air.set_index(["Activity Period","Operating Airline"],inplace=True)

# %%
air.head(5)
# Out:
#                                   Operating Airline IATA Code  \
# Activity Period Operating Airline
# 200507          ATA Airlines                               TZ
#                 ATA Airlines                               TZ
#                 ATA Airlines                               TZ
#                 Air Canada                                 AC
#                 Air Canada                                 AC
#
#                                   Published Airline  \
# Activity Period Operating Airline
# 200507          ATA Airlines           ATA Airlines
#                 ATA Airlines           ATA Airlines
#                 ATA Airlines           ATA Airlines
#                 Air Canada               Air Canada
#                 Air Canada               Air Canada
#
#                                   Published Airline IATA Code    GEO Summary  \
# Activity Period Operating Airline
# 200507          ATA Airlines                               TZ       Domestic
# ...

# %%
air.sort_index(ascending=[False,True],inplace=True)

# %%
air.head(5)
# Out:
#                                                          Operating Airline IATA Code  \
# Activity Period Operating Airline
# 201803          ABC Aerolineas S.A. de C.V. dba Interjet                          4O
#                 ABC Aerolineas S.A. de C.V. dba Interjet                          4O
#                 Aer Lingus                                                        EI
#                 Aer Lingus                                                        EI
#                 Aeromexico                                                        AM
#
#                                                                                  Published Airline  \
# Activity Period Operating Airline
# 201803          ABC Aerolineas S.A. de C.V. dba Interjet  ABC Aerolineas S.A. de C.V. dba Interjet
#                 ABC Aerolineas S.A. de C.V. dba Interjet  ABC Aerolineas S.A. de C.V. dba Interjet
# ...

# %%
air.reset_index(inplace=True)

# %%
air.head()
# Out:
#    Activity Period                         Operating Airline  \
# 0           201803  ABC Aerolineas S.A. de C.V. dba Interjet
# 1           201803  ABC Aerolineas S.A. de C.V. dba Interjet
# 2           201803                                Aer Lingus
# 3           201803                                Aer Lingus
# 4           201803                                Aeromexico
#
#   Operating Airline IATA Code                         Published Airline  \
# 0                          4O  ABC Aerolineas S.A. de C.V. dba Interjet
# 1                          4O  ABC Aerolineas S.A. de C.V. dba Interjet
# 2                          EI                                Aer Lingus
# 3                          EI                                Aer Lingus
# 4                          AM                                Aeromexico
#
#   Published Airline IATA Code    GEO Summary GEO Region Activity Type Code  \
# 0                          4O  International     Mexico           Deplaned
# ...

# %%
air.set_index(["Activity Period","Operating Airline","Activity Type Code"],inplace=True)

# %%
air.head(5)
# Out:
#                                                                             Operating Airline IATA Code  \
# Activity Period Operating Airline                        Activity Type Code
# 201803          ABC Aerolineas S.A. de C.V. dba Interjet Deplaned                                    4O
#                                                          Enplaned                                    4O
#                 Aer Lingus                               Deplaned                                    EI
#                                                          Enplaned                                    EI
#                 Aeromexico                               Deplaned                                    AM
#
#                                                                                                     Published Airline  \
# Activity Period Operating Airline                        Activity Type Code
# ...

# %% [markdown]
# ## 102 Wyszukiwanie danych w multiindeksie - wykład

# %% [markdown]
# ## 104 LAB 2: Wyszukiwanie danych w multiindeksie

# %%
air=pd.read_csv("./Air_Traffic_Passenger_Statistics.csv")

# %%
air.set_index(["Operating Airline","Activity Period","Activity Type Code",],inplace=True)

# %%
air.head(1)
# Out:
#                                                                             Operating Airline IATA Code  \
# Operating Airline                        Activity Period Activity Type Code
# ABC Aerolineas S.A. de C.V. dba Interjet 201803          Deplaned                                    4O
#
#                                                                                                     Published Airline  \
# Operating Airline                        Activity Period Activity Type Code
# ABC Aerolineas S.A. de C.V. dba Interjet 201803          Deplaned            ABC Aerolineas S.A. de C.V. dba Interjet
#
#                                                                             Published Airline IATA Code  \
# Operating Airline                        Activity Period Activity Type Code
# ABC Aerolineas S.A. de C.V. dba Interjet 201803          Deplaned                                    4O
#
# ...

# %%
air.sort_index(inplace=True)

# %%
air.loc[('Air France',200507,'Enplaned')]
# Out:
#                                                      Operating Airline IATA Code  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned                                    AF
#
#                                                      Published Airline  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned                  Air France
#
#                                                      Published Airline IATA Code  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned                                    AF
#
#                                                         GEO Summary  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned            International
#
#                                                      GEO Region  \
# Operating Airline Activity Period Activity Type Code
# ...

# %%
air.loc[('Air France',200507)]
# Out:
#                    Operating Airline IATA Code Published Airline  \
# Activity Type Code
# Deplaned                                    AF        Air France
# Enplaned                                    AF        Air France
#
#                    Published Airline IATA Code    GEO Summary GEO Region  \
# Activity Type Code
# Deplaned                                    AF  International     Europe
# Enplaned                                    AF  International     Europe
#
#                    Price Category Code       Terminal Boarding Area  \
# Activity Type Code
# Deplaned                         Other  International             A
# Enplaned                         Other  International             A
#
#                     Passenger Count
# Activity Type Code
# Deplaned                      12050
# Enplaned                      11638

# %%
air.loc[('Air France')].head(5)
# Out:
#                                    Operating Airline IATA Code  \
# Activity Period Activity Type Code
# 200507          Deplaned                                    AF
#                 Enplaned                                    AF
# 200508          Deplaned                                    AF
#                 Enplaned                                    AF
# 200509          Deplaned                                    AF
#
#                                    Published Airline  \
# Activity Period Activity Type Code
# 200507          Deplaned                  Air France
#                 Enplaned                  Air France
# 200508          Deplaned                  Air France
#                 Enplaned                  Air France
# 200509          Deplaned                  Air France
#
#                                    Published Airline IATA Code    GEO Summary  \
# Activity Period Activity Type Code
# ...

# %%
air.loc[('Air France',200507,'Enplaned'),"Passenger Count"]
# Out:
# Operating Airline  Activity Period  Activity Type Code
# Air France         200507           Enplaned              11638
# Name: Passenger Count, dtype: int64

# %%
air.loc[('Air France',200507,'Deplaned'),"Passenger Count"]
# Out:
# Operating Airline  Activity Period  Activity Type Code
# Air France         200507           Deplaned              12050
# Name: Passenger Count, dtype: int64

# %%
air.iloc[20:25]
# Out:
#                                                      Operating Airline IATA Code  \
# Operating Airline Activity Period Activity Type Code
# ATA Airlines      200512          Enplaned                                    TZ
#                                   Thru / Transit                              TZ
#                   200601          Deplaned                                    TZ
#                                   Enplaned                                    TZ
#                                   Thru / Transit                              TZ
#
#                                                      Published Airline  \
# Operating Airline Activity Period Activity Type Code
# ATA Airlines      200512          Enplaned                ATA Airlines
#                                   Thru / Transit          ATA Airlines
#                   200601          Deplaned                ATA Airlines
#                                   Enplaned                ATA Airlines
# ...

# %%
air.iloc[20:25,8]
# Out:
# Operating Airline  Activity Period  Activity Type Code
# ATA Airlines       200512           Enplaned              16790
#                                     Thru / Transit         2402
#                    200601           Deplaned              13010
#                                     Enplaned              12226
#                                     Thru / Transit         3316
# Name: Passenger Count, dtype: int64

# %% [markdown]
# ## 105. Transpozycja - wykład

# %% [markdown]
# ## 107. LAB3: Transpozycja

# %%
fuel=pd.read_csv("./fuel.csv", usecols=['Year','Make','Model','Range (FT1)','City Range (FT1)'],
                 index_col=['Year','Make','Model'])

# %%
fuel.head(1)
# Out:
#                            Range (FT1)  City Range (FT1)
# Year Make       Model
# 1984 Alfa Romeo GT V6 2.5          0.0               0.0

# %%
fuel.loc[(1984)].head()
# Out:
#                                Range (FT1)  City Range (FT1)
# Make       Model
# Alfa Romeo GT V6 2.5                   0.0               0.0
#            GT V6 2.5                   0.0               0.0
#            Spider Veloce 2000          0.0               0.0
#            Spider Veloce 2000          0.0               0.0
# AM General DJ Po Vehicle 2WD           0.0               0.0

# %%
fuel.loc[(1984,'Alfa Romeo')].head()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6060\3033487557.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   fuel.loc[(1984,'Alfa Romeo')].head()
#                     Range (FT1)  City Range (FT1)
# Model
# GT V6 2.5                   0.0               0.0
# GT V6 2.5                   0.0               0.0
# Spider Veloce 2000          0.0               0.0
# Spider Veloce 2000          0.0               0.0

# %%
fuel.loc[(1984,'Alfa Romeo','Spider Veloce 2000')].head()
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6060\2574967649.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   fuel.loc[(1984,'Alfa Romeo','Spider Veloce 2000')].head()
#                                     Range (FT1)  City Range (FT1)
# Year Make       Model
# 1984 Alfa Romeo Spider Veloce 2000          0.0               0.0
#                 Spider Veloce 2000          0.0               0.0

# %%
fuel.loc[(1984,'Alfa Romeo','Spider Veloce 2000'),'Range (FT1)']
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6060\861120849.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   fuel.loc[(1984,'Alfa Romeo','Spider Veloce 2000'),'Range (FT1)']
# Year  Make        Model
# 1984  Alfa Romeo  Spider Veloce 2000    0.0
#                   Spider Veloce 2000    0.0
# Name: Range (FT1), dtype: float64

# %%
fuel=fuel.transpose()

# %%
fuel.head()
# Out:
# Year                   1984                                                  \
# Make             Alfa Romeo
# Model             GT V6 2.5 GT V6 2.5 Spider Veloce 2000 Spider Veloce 2000
# Range (FT1)             0.0       0.0                0.0                0.0
# City Range (FT1)        0.0       0.0                0.0                0.0
#
# Year                                                                   \
# Make                    AM General
# Model            DJ Po Vehicle 2WD DJ Po Vehicle 2WD FJ8c Post Office
# Range (FT1)                    0.0               0.0              0.0
# City Range (FT1)               0.0               0.0              0.0
#
# Year                                                                     ...  \
# Make                              American Motors Corporation            ...
# Model            FJ8c Post Office                   Eagle 4WD Eagle 4WD  ...
# Range (FT1)                   0.0                         0.0       0.0  ...
# ...

# %%
fuel.loc["Range (FT1)"]
# Out:
# Year  Make        Model
# 1984  Alfa Romeo  GT V6 2.5             0.0
#                   GT V6 2.5             0.0
#                   Spider Veloce 2000    0.0
#                   Spider Veloce 2000    0.0
#       AM General  DJ Po Vehicle 2WD     0.0
#                                        ...
# 2012  Mitsubishi  Lancer                0.0
#                   Lancer AWD            0.0
#                   Lancer Evolution      0.0
#                   Lancer Evolution      0.0
#       Mitsubish   NaN                   NaN
# Name: Range (FT1), Length: 31684, dtype: float64

# %%
fuel.loc["Range (FT1)",1984]
# Out:
# Make        Model
# Alfa Romeo  GT V6 2.5             0.0
#             GT V6 2.5             0.0
#             Spider Veloce 2000    0.0
#             Spider Veloce 2000    0.0
# AM General  DJ Po Vehicle 2WD     0.0
#                                  ...
# Volvo       760 GLE               0.0
#             760 GLE               0.0
#             760 GLE               0.0
#             760 GLE               0.0
#             760 GLE               0.0
# Name: Range (FT1), Length: 1964, dtype: float64

# %%
fuel.loc["Range (FT1)",(1984,"Alfa Romeo")]
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6060\686943528.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   fuel.loc["Range (FT1)",(1984,"Alfa Romeo")]
# Model
# GT V6 2.5             0.0
# GT V6 2.5             0.0
# Spider Veloce 2000    0.0
# Spider Veloce 2000    0.0
# Name: Range (FT1), dtype: float64

# %%
fuel.loc["Range (FT1)",(1984,"Alfa Romeo","Spider Veloce 2000")]
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6060\2766575737.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   fuel.loc["Range (FT1)",(1984,"Alfa Romeo","Spider Veloce 2000")]
# Year  Make        Model
# 1984  Alfa Romeo  Spider Veloce 2000    0.0
#                   Spider Veloce 2000    0.0
# Name: Range (FT1), dtype: float64

# %% [markdown]
# ## 106. Swaplevel - wykład

# %% [markdown]
# ## 107. LAB 4: Swaplevel

# %%
fuel=pd.read_csv("./fuel.csv", usecols=['Year','Make','Model','Range (FT1)','City Range (FT1)'],
                 index_col=['Year','Make','Model'])

# %%
fuel.sort_index().head(5)
# Out:
#                                    Range (FT1)  City Range (FT1)
# Year Make       Model
# 1984 AM General DJ Po Vehicle 2WD          0.0               0.0
#                 DJ Po Vehicle 2WD          0.0               0.0
#                 FJ8c Post Office           0.0               0.0
#                 FJ8c Post Office           0.0               0.0
#      Alfa Romeo GT V6 2.5                  0.0               0.0

# %%
fuel.loc[(1984,"Alfa Romeo",'Spider Veloce 2000')]
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_6060\1619888094.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   fuel.loc[(1984,"Alfa Romeo",'Spider Veloce 2000')]
#                                     Range (FT1)  City Range (FT1)
# Year Make       Model
# 1984 Alfa Romeo Spider Veloce 2000          0.0               0.0
#                 Spider Veloce 2000          0.0               0.0

# %%
fuel=fuel.swaplevel(0,1).sort_index()

# %%
fuel.sort_index(inplace=True)
fuel.head()
# Out:
#                                      Range (FT1)  City Range (FT1)
# Make       Year Model
# AM General 1984 DJ Po Vehicle 2WD            0.0               0.0
#                 DJ Po Vehicle 2WD            0.0               0.0
#                 FJ8c Post Office             0.0               0.0
#                 FJ8c Post Office             0.0               0.0
#            1985 Post Office DJ5 2WD          0.0               0.0

# %%
fuel.loc[("Alfa Romeo",1984,'Spider Veloce 2000')]
# Out:
#                                     Range (FT1)  City Range (FT1)
# Make       Year Model
# Alfa Romeo 1984 Spider Veloce 2000          0.0               0.0
#                 Spider Veloce 2000          0.0               0.0

# %%
fuel=fuel.swaplevel(1,2)

# %%
fuel.sort_index(inplace=True)

# %%
fuel.head()
# Out:
#                                      Range (FT1)  City Range (FT1)
# Make       Model               Year
# AM General DJ Po Vehicle 2WD   1984          0.0               0.0
#                                1984          0.0               0.0
#            FJ8c Post Office    1984          0.0               0.0
#                                1984          0.0               0.0
#            Post Office DJ5 2WD 1985          0.0               0.0

# %%
fuel.loc[("Alfa Romeo",'Spider Veloce 2000',1984)]
# Out:
#                                     Range (FT1)  City Range (FT1)
# Make       Model              Year
# Alfa Romeo Spider Veloce 2000 1984          0.0               0.0
#                               1984          0.0               0.0

# %% [markdown]
# ## 108. Stuck i unstuck - wykład

# %% [markdown]
# ## 109. LAB 5: Stuck i unstuck

# %%
import pandas as pd
fuel=pd.read_csv("./fuel.csv", usecols=['Year','Make','Model','Range (FT1)','City Range (FT1)'])

# %%
fuel.head(5)
# Out:
#    Year        Make               Model  Range (FT1)  City Range (FT1)
# 0  1984  Alfa Romeo           GT V6 2.5          0.0               0.0
# 1  1984  Alfa Romeo           GT V6 2.5          0.0               0.0
# 2  1984  Alfa Romeo  Spider Veloce 2000          0.0               0.0
# 3  1984  Alfa Romeo  Spider Veloce 2000          0.0               0.0
# 4  1984  AM General   DJ Po Vehicle 2WD          0.0               0.0

# %%
fuel.drop_duplicates(subset=['Year','Make','Model'],inplace=True)

# %%
fuel.dropna(inplace=True)

# %%
fuel.set_index(['Year','Make','Model'],inplace=True)

# %%
fuel.head()
# Out:
#                                                      Range (FT1)  \
# Year Make                        Model
# 1984 Alfa Romeo                  GT V6 2.5                   0.0
#                                  Spider Veloce 2000          0.0
#      AM General                  DJ Po Vehicle 2WD           0.0
#                                  FJ8c Post Office            0.0
#      American Motors Corporation Eagle 4WD                   0.0
#
#                                                      City Range (FT1)
# Year Make                        Model
# 1984 Alfa Romeo                  GT V6 2.5                        0.0
#                                  Spider Veloce 2000               0.0
#      AM General                  DJ Po Vehicle 2WD                0.0
#                                  FJ8c Post Office                 0.0
#      American Motors Corporation Eagle 4WD                        0.0

# %%
fuel.stack().head()
# Out:
# Year  Make        Model
# 1984  Alfa Romeo  GT V6 2.5           Range (FT1)         0.0
#                                       City Range (FT1)    0.0
#                   Spider Veloce 2000  Range (FT1)         0.0
#                                       City Range (FT1)    0.0
#       AM General  DJ Po Vehicle 2WD   Range (FT1)         0.0
# dtype: float64

# %%
fuel.stack().to_frame().head()
# Out:
#                                                        0
# Year Make       Model
# 1984 Alfa Romeo GT V6 2.5          Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#                 Spider Veloce 2000 Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#      AM General DJ Po Vehicle 2WD  Range (FT1)       0.0

# %%
fuel.unstack().head()
# Out:
#                                  Range (FT1)                             \
# Model                                 09-Mar 09-May 1-Ton Truck 2WD 100
# Year Make
# 1984 AM General                          NaN    NaN             NaN NaN
#      Alfa Romeo                          NaN    NaN             NaN NaN
#      American Motors Corporation         NaN    NaN             NaN NaN
#      Aston Martin                        NaN    NaN             NaN NaN
#      Audi                                NaN    NaN             NaN NaN
#
#                                                                                \
# Model                            100 Wagon 100 quattro 100 quattro Wagon 1000
# Year Make
# 1984 AM General                        NaN         NaN               NaN  NaN
#      Alfa Romeo                        NaN         NaN               NaN  NaN
#      American Motors Corporation       NaN         NaN               NaN  NaN
# ...

# %%
fuel.unstack("Year").head()
# Out:
#                                      Range (FT1)                           \
# Year                                        1984 1985 1986 1987 1988 1989
# Make             Model
# AM General       DJ Po Vehicle 2WD           0.0  NaN  NaN  NaN  NaN  NaN
#                  FJ8c Post Office            0.0  NaN  NaN  NaN  NaN  NaN
#                  Post Office DJ5 2WD         NaN  0.0  NaN  NaN  NaN  NaN
#                  Post Office DJ8 2WD         NaN  0.0  NaN  NaN  NaN  NaN
# ASC Incorporated GNX                         NaN  NaN  NaN  0.0  NaN  NaN
#
#                                                           ...  \
# Year                                 1990 1991 1992 1993  ...
# Make             Model                                    ...
# AM General       DJ Po Vehicle 2WD    NaN  NaN  NaN  NaN  ...
#                  FJ8c Post Office     NaN  NaN  NaN  NaN  ...
#                  Post Office DJ5 2WD  NaN  NaN  NaN  NaN  ...
# ...

# %%
fuel.stack().head()
# Out:
# Year  Make        Model
# 1984  Alfa Romeo  GT V6 2.5           Range (FT1)         0.0
#                                       City Range (FT1)    0.0
#                   Spider Veloce 2000  Range (FT1)         0.0
#                                       City Range (FT1)    0.0
#       AM General  DJ Po Vehicle 2WD   Range (FT1)         0.0
# dtype: float64

# %%
fuel.stack().to_frame().head()
# Out:
#                                                        0
# Year Make       Model
# 1984 Alfa Romeo GT V6 2.5          Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#                 Spider Veloce 2000 Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#      AM General DJ Po Vehicle 2WD  Range (FT1)       0.0

# %%
fuel.stack().to_frame().unstack("Year").head()
# Out:
#                                                    0                           \
# Year                                            1984 1985 1986 1987 1988 1989
# Make       Model
# AM General DJ Po Vehicle 2WD   Range (FT1)       0.0  NaN  NaN  NaN  NaN  NaN
#                                City Range (FT1)  0.0  NaN  NaN  NaN  NaN  NaN
#            FJ8c Post Office    Range (FT1)       0.0  NaN  NaN  NaN  NaN  NaN
#                                City Range (FT1)  0.0  NaN  NaN  NaN  NaN  NaN
#            Post Office DJ5 2WD Range (FT1)       NaN  0.0  NaN  NaN  NaN  NaN
#
#                                                                      ...       \
# Year                                            1990 1991 1992 1993  ... 2003
# Make       Model                                                     ...
# AM General DJ Po Vehicle 2WD   Range (FT1)       NaN  NaN  NaN  NaN  ...  NaN
#                                City Range (FT1)  NaN  NaN  NaN  NaN  ...  NaN
# ...

# %%
fuel.stack().to_frame().unstack("Make").head()
# Out:
#                                                    0                         \
# Make                                      AM General ASC Incorporated Acura
# Year Model
# 1984 1000                Range (FT1)             NaN              NaN   NaN
#                          City Range (FT1)        NaN              NaN   NaN
#      18i                 Range (FT1)             NaN              NaN   NaN
#                          City Range (FT1)        NaN              NaN   NaN
#      190 D 2.2/190 E 2.3 Range (FT1)             NaN              NaN   NaN
#
#                                                       \
# Make                                      Alfa Romeo
# Year Model
# 1984 1000                Range (FT1)             NaN
#                          City Range (FT1)        NaN
#      18i                 Range (FT1)             NaN
#                          City Range (FT1)        NaN
#      190 D 2.2/190 E 2.3 Range (FT1)             NaN
#
# ...

# %%
fuel.stack().to_frame().unstack(["Year","Make"]).head()
# Out:
#                                           0             \
# Year                                   1984
# Make                             Alfa Romeo AM General
# Model
# 09-Mar          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 09-May          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 1-Ton Truck 2WD Range (FT1)             NaN        NaN
#
#                                                                            \
# Year
# Make                             American Motors Corporation Aston Martin
# Model
# 09-Mar          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# 09-May          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# ...

# %%
fuel.stack().to_frame().unstack(level=["Make","Year"]).sort_index(axis=1).head()
# Out:
#                                           0                                   \
# Make                             AM General      ASC Incorporated Acura
# Year                                   1984 1985             1987  1986 1987
# Model
# 09-Mar          Range (FT1)             NaN  NaN              NaN   NaN  NaN
#                 City Range (FT1)        NaN  NaN              NaN   NaN  NaN
# 09-May          Range (FT1)             NaN  NaN              NaN   NaN  NaN
#                 City Range (FT1)        NaN  NaN              NaN   NaN  NaN
# 1-Ton Truck 2WD Range (FT1)             NaN  NaN              NaN   NaN  NaN
#
#                                                            ...  \
# Make                                                       ...
# Year                             1988 1989 1990 1991 1992  ...
# Model                                                      ...
# 09-Mar          Range (FT1)       NaN  NaN  NaN  NaN  NaN  ...
# ...

# %% [markdown]
# ## 110. Tabele przestawne - wykład

# %%
sales=pd.read_csv("./WA_Sales_Products_2012-14.csv")
sales.head(1)
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
#
#    Product type                    Product  Year  Quarter   Revenue  Quantity  \
# 0  Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012  59628.66       489
#
#    Gross margin
# 0      0.347548

# %%
sales.pivot_table(index="Retailer country", columns=["Year", "Quarter"], values="Revenue").head()
# Out:
# Year                      2012                                            \
# Quarter                Q1 2012       Q2 2012       Q3 2012       Q4 2012
# Retailer country
# Australia         18906.876142  16895.175467  17504.806761  19768.131373
# Austria           25401.670751  23912.953258  23179.373278  23859.805094
# Belgium           24773.419214  21039.834690  20731.776829  24487.121476
# Brazil            24750.126262  29493.933430  29727.165405  28584.067967
# Canada            32925.458510  31271.184460  30955.907339  35278.634815
#
# Year                      2013                                            \
# Quarter                Q1 2013       Q2 2013       Q3 2013       Q4 2013
# Retailer country
# Australia         30539.494720  37051.540029  34052.142800  37522.124826
# Austria           30688.525339  29262.090053  27345.137760  35773.766921
# Belgium           22647.458500  27962.299003  24955.905244  28422.705106
# ...

# %%
sales.pivot_table(index="Retailer country", columns="Year", values="Revenue").head()
# Out:
# Year                      2012          2013          2014
# Retailer country
# Australia         18264.652996  34738.181061  40465.826945
# Austria           24072.485815  30630.862519  35320.573647
# Belgium           22700.744951  25911.838406  31670.606449
# Brazil            28107.451806  34711.962928  38342.489610
# Canada            32610.629524  43712.280352  53718.102117

# %%
SalesPivot=sales.pivot_table(index="Retailer country", columns="Year", values="Gross margin", aggfunc=["min","max"])
SalesPivot.head(1)
# Out:
#                        min                           max
# Year                  2012      2013      2014      2012      2013      2014
# Retailer country
# Australia        -0.389517  0.000766  0.000766  0.770476  0.763231  0.757143

# %%
SalesPivot.swaplevel(0,1,axis=1).head()
# Out:
# Year                  2012      2013      2014      2012      2013      2014
#                        min       min       min       max       max       max
# Retailer country
# Australia        -0.389517  0.000766  0.000766  0.770476  0.763231  0.757143
# Austria           0.052200 -0.030436 -0.086616  0.770476  0.763231  0.759734
# Belgium          -1.476136  0.000766  0.000766  0.770476  0.767760  0.759618
# Brazil           -0.681869 -2.085496 -0.291963  0.770476  0.767760  0.758840
# Canada           -1.373907 -0.741547 -0.050334  0.770476  0.767760  0.757660

# %%
SalesPivot.swaplevel(0,1,axis=1).sort_index(axis=1).head()
# Out:
# Year                  2012                2013                2014
#                        max       min       max       min       max       min
# Retailer country
# Australia         0.770476 -0.389517  0.763231  0.000766  0.757143  0.000766
# Austria           0.770476  0.052200  0.763231 -0.030436  0.759734 -0.086616
# Belgium           0.770476 -1.476136  0.767760  0.000766  0.759618  0.000766
# Brazil            0.770476 -0.681869  0.767760 -2.085496  0.758840 -0.291963
# Canada            0.770476 -1.373907  0.767760 -0.741547  0.757660 -0.050334

# %% [markdown]
# ## 111. LAB 6: Tabele przestawne

# %%
import numpy as np
from datetime import datetime
from datetime import timedelta
import time as time

# %%
df=pd.read_csv("./marathon_results_2016.csv", usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'],
               index_col="Bib")

# %%
df['40K'] = df['40K'].replace('-', 0)
df['Half'] = df['Half'].replace('-', 0)

df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)
df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))

# %%
df.head()
# Out:
#      Age M/F         City State Country            Half             40K  \
# Bib
# 5     21   M  Addis Ababa   NaN     ETH 0 days 01:06:45 0 days 02:05:59
# 1     26   M         Ambo   NaN     ETH 0 days 01:06:46 0 days 02:05:59
# 6     31   M  Addis Ababa   NaN     ETH 0 days 01:06:44 0 days 02:06:47
# 11    33   M       Kitale   NaN     KEN 0 days 01:06:46 0 days 02:06:47
# 14    23   M      Eldoret   NaN     KEN 0 days 01:06:46 0 days 02:08:11
#
#         Pace  TotalSeconds  HalfSeconds
# Bib
# 5    0:05:04        7559.0       4005.0
# 1    0:05:06        7559.0       4006.0
# 6    0:05:07        7607.0       4004.0
# 11   0:05:07        7607.0       4006.0
# 14   0:05:11        7691.0       4006.0

# %%
df.pivot_table(index="Age", columns="M/F", values="TotalSeconds", aggfunc="mean").head()
# Out:
# M/F             F             M
# Age
# 18   16050.666667  14554.615385
# 19   15351.958333  12156.529412
# 20   13835.931818  12111.100000
# 21   14681.027027  12408.360465
# 22   14366.421053  11872.666667

# %%
dfPivot=df.pivot_table(index="Age", columns="M/F", values=["TotalSeconds", "HalfSeconds"], aggfunc="mean")
dfPivot.head()
# Out:
#      HalfSeconds               TotalSeconds
# M/F            F            M             F             M
# Age
# 18   7999.888889  7078.538462  16050.666667  14554.615385
# 19   7473.666667  5817.764706  15351.958333  12156.529412
# 20   6871.045455  5716.800000  13835.931818  12111.100000
# 21   7148.554054  5929.627907  14681.027027  12408.360465
# 22   7091.097744  5751.000000  14366.421053  11872.666667

# %%
dfPivot.swaplevel(axis=1).sort_index(axis=1).head()
# Out:
# M/F            F                          M
#      HalfSeconds  TotalSeconds  HalfSeconds  TotalSeconds
# Age
# 18   7999.888889  16050.666667  7078.538462  14554.615385
# 19   7473.666667  15351.958333  5817.764706  12156.529412
# 20   6871.045455  13835.931818  5716.800000  12111.100000
# 21   7148.554054  14681.027027  5929.627907  12408.360465
# 22   7091.097744  14366.421053  5751.000000  11872.666667

# %%
df.pivot_table(index="Age", columns=["M/F"], values="TotalSeconds", aggfunc="count").head()
# Out:
# M/F      F     M
# Age
# 18     9.0  13.0
# 19    24.0  17.0
# 20    44.0  40.0
# 21    74.0  86.0
# 22   133.0  93.0

# %%
df.pivot_table(index="Country", aggfunc="count", values="TotalSeconds").head()
# Out:
#          TotalSeconds
# Country
# ALB                 1
# AND                 1
# ARG                26
# AUS               152
# AUT                27

# %%
df.pivot_table(index="Country", aggfunc="count", values="TotalSeconds").sort_values("TotalSeconds", ascending=True).head()
# Out:
#          TotalSeconds
# Country
# ALB                 1
# VGB                 1
# UGA                 1
# ROU                 1
# PAK                 1

# %%
dfPivot2=df.pivot_table(index=["Country", "State", "City"], values="TotalSeconds", aggfunc="mean").sort_values("TotalSeconds",
                                                                                                     ascending=False)
dfPivot2.head()
# Out:
#                             TotalSeconds
# Country State City
# USA     WI    Reedsburg          28461.0
#         TX    Justin             23816.0
#         MS    Olive Branch       21878.0
#         FL    Estero             21468.0
#         TX    Fresno             20919.0

# %%
dfPivot2.iloc[:,0]
# Out:
# Country  State  City
# USA      WI     Reedsburg       28461.0
#          TX     Justin          23816.0
#          MS     Olive Branch    21878.0
#          FL     Estero          21468.0
#          TX     Fresno          20919.0
#                                  ...
#          NE     Kearney          8354.0
#          NY     New Paltz        8182.0
#          PA     Sellersville     6399.0
#          CA     Rossmoor            0.0
#          MN     Northfield          0.0
# Name: TotalSeconds, Length: 5439, dtype: float64

# %%
df["meanTotalSeconds"]=dfPivot2

# %%
df.head()
# Out:
#                             TotalSeconds  meanTotalSeconds
# Country State City
# USA     WI    Reedsburg          28461.0           28461.0
#         TX    Justin             23816.0           23816.0
#         MS    Olive Branch       21878.0           21878.0
#         FL    Estero             21468.0           21468.0
#         TX    Fresno             20919.0           20919.0

# %% [markdown]
# ## 112. Polecenie melt = wykład

# %%
sales=pd.read_csv("./WA_Sales_Products_2012-14.csv")

# %%
sales.head(1)
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
#
#    Product type                    Product  Year  Quarter   Revenue  Quantity  \
# 0  Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012  59628.66       489
#
#    Gross margin
# 0      0.347548

# %%
salesPivot=sales.pivot_table(index="Retailer country", columns="Year", values="Revenue", aggfunc="sum")

# %%
salesPivot.head(5)
# Out:
# Year                     2012         2013         2014
# Retailer country
# Australia         25607043.50  47799737.14  35893188.50
# Austria           34568089.63  44996737.04  33801788.98
# Belgium           30396297.49  38375432.68  28186839.74
# Brazil            34234876.30  43389953.66  31440841.48
# Canada            75428386.09  98134069.39  73325209.39

# %%
salesPivot.reset_index(inplace=True)

# %%
salesPivot.head(5)
# Out:
# Year Retailer country         2012         2013         2014
# 0           Australia  25607043.50  47799737.14  35893188.50
# 1             Austria  34568089.63  44996737.04  33801788.98
# 2             Belgium  30396297.49  38375432.68  28186839.74
# 3              Brazil  34234876.30  43389953.66  31440841.48
# 4              Canada  75428386.09  98134069.39  73325209.39

# %%
salesPivot.fillna(0, inplace=True)

# %%
salesPivot.melt(id_vars="Retailer country", value_vars=[2012,2013,2014], var_name="Years", value_name="Revenue").head()
# Out:
#   Retailer country Years      Revenue
# 0        Australia  2012  25607043.50
# 1          Austria  2012  34568089.63
# 2          Belgium  2012  30396297.49
# 3           Brazil  2012  34234876.30
# 4           Canada  2012  75428386.09

# %% [markdown]
# ## 113. LAB 7: Polecenie melt

# %%
from datetime import datetime
from datetime import timedelta
import time

# %%
df = pd.read_csv('./marathon_results_2016.csv', index_col='Bib',
usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])

df['40K'] = df['40K'].replace('-', 0)
df['Half'] = df['Half'].replace('-', 0)

df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)

df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))

df = df.pivot_table(index="Age",columns="M/F",values="TotalSeconds", aggfunc="mean")
df.head()
# Out:
# M/F             F             M
# Age
# 18   16050.666667  14554.615385
# 19   15351.958333  12156.529412
# 20   13835.931818  12111.100000
# 21   14681.027027  12408.360465
# 22   14366.421053  11872.666667

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
# M/F  index  Age             F             M
# 0        0   18  16050.666667  14554.615385
# 1        1   19  15351.958333  12156.529412
# 2        2   20  13835.931818  12111.100000
# 3        3   21  14681.027027  12408.360465
# 4        4   22  14366.421053  11872.666667

# %%
df.melt(id_vars="Age", value_vars=["F","M"], value_name="TotalSeconds", var_name="Sex").head()
# Out:
#    Age Sex  TotalSeconds
# 0   18   F  16050.666667
# 1   19   F  15351.958333
# 2   20   F  13835.931818
# 3   21   F  14681.027027
# 4   22   F  14366.421053

# %%
df = pd.read_csv('./marathon_results_2016.csv', index_col='Bib',
 usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])
          
df['40K'] = df['40K'].replace('-', 0)
df['Half'] = df['Half'].replace('-', 0)
    
df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)
          
df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))
          
df = df.pivot_table(index="Age",columns="M/F",values=["HalfSeconds","TotalSeconds"]).head()
                                                      
df.head()
# Out:
#      HalfSeconds               TotalSeconds
# M/F            F            M             F             M
# Age
# 18   7999.888889  7078.538462  16050.666667  14554.615385
# 19   7473.666667  5817.764706  15351.958333  12156.529412
# 20   6871.045455  5716.800000  13835.931818  12111.100000
# 21   7148.554054  5929.627907  14681.027027  12408.360465
# 22   7091.097744  5751.000000  14366.421053  11872.666667

# %%
df.reset_index(inplace=True)

# %%
df.melt(id_vars="Age", value_name="Time").head()
# Out:
#    Age         None M/F         Time
# 0   18  HalfSeconds   F  7999.888889
# 1   19  HalfSeconds   F  7473.666667
# 2   20  HalfSeconds   F  6871.045455
# 3   21  HalfSeconds   F  7148.554054
# 4   22  HalfSeconds   F  7091.097744

# %% [markdown]
# ## 114. Metadata multiindeksu - wykład

# %% [markdown]
# ## 115. LAB 8: Metadata multiindeksu

# %%
air=pd.read_csv("./Air_Traffic_Passenger_Statistics.csv")

# %%
air.index
# Out:
# RangeIndex(start=0, stop=18398, step=1)

# %%
air.set_index(["Operating Airline","Activity Period"],inplace=True)

# %%
air.head()
# Out:
#                                   Operating Airline IATA Code  \
# Operating Airline Activity Period
# ATA Airlines      200507                                   TZ
#                   200507                                   TZ
#                   200507                                   TZ
# Air Canada        200507                                   AC
#                   200507                                   AC
#
#                                   Published Airline  \
# Operating Airline Activity Period
# ATA Airlines      200507               ATA Airlines
#                   200507               ATA Airlines
#                   200507               ATA Airlines
# Air Canada        200507                 Air Canada
#                   200507                 Air Canada
#
#                                   Published Airline IATA Code    GEO Summary  \
# Operating Airline Activity Period
# ATA Airlines      200507                                   TZ       Domestic
# ...

# %%
air.index
# Out:
# MultiIndex([(    'ATA Airlines', 200507),
#             (    'ATA Airlines', 200507),
#             (    'ATA Airlines', 200507),
#             (      'Air Canada', 200507),
#             (      'Air Canada', 200507),
#             (       'Air China', 200507),
#             (       'Air China', 200507),
#             (      'Air France', 200507),
#             (      'Air France', 200507),
#             ( 'Air New Zealand', 200507),
#             ...
#             (  'Virgin America', 201803),
#             (  'Virgin America', 201803),
#             (  'Virgin America', 201803),
#             ( 'Virgin Atlantic', 201803),
#             ( 'Virgin Atlantic', 201803),
#             ('Volaris Airlines', 201803),
#             ('Volaris Airlines', 201803),
#             (         'WOW Air', 201803),
#             (         'WOW Air', 201803),
#             (         'WOW Air', 201803)],
#            names=['Operating Airline', 'Activity Period'], length=18398)

# %%
air.index.get_level_values(0)
# Out:
# Index(['ATA Airlines', 'ATA Airlines', 'ATA Airlines', 'Air Canada',
#        'Air Canada', 'Air China', 'Air China', 'Air France', 'Air France',
#        'Air New Zealand',
#        ...
#        'Virgin America', 'Virgin America', 'Virgin America', 'Virgin Atlantic',
#        'Virgin Atlantic', 'Volaris Airlines', 'Volaris Airlines', 'WOW Air',
#        'WOW Air', 'WOW Air'],
#       dtype='object', name='Operating Airline', length=18398)

# %%
air.index.get_level_values(1)
# Out:
# Int64Index([200507, 200507, 200507, 200507, 200507, 200507, 200507, 200507,
#             200507, 200507,
#             ...
#             201803, 201803, 201803, 201803, 201803, 201803, 201803, 201803,
#             201803, 201803],
#            dtype='int64', name='Activity Period', length=18398)

# %%
air.index.names
# Out:
# FrozenList(['Operating Airline', 'Activity Period'])
